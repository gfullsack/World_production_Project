# %%
import pandas as pd
from sqlalchemy import create_engine
import json
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)
db = client['SF_Restaurant_db']

# %%
csv_file = "Resources/FAO.csv"
Raw_Master_df = pd.read_csv(csv_file , encoding='latin-1')
Raw_Master_df.head(5)
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0               AFG          2  Afghanistan       2511
# 1               AFG          2  Afghanistan       2805
# 2               AFG          2  Afghanistan       2513
# 3               AFG          2  Afghanistan       2513
# 4               AFG          2  Afghanistan       2514
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 2       Barley and products          5521    Feed  1000 tonnes     33.94
# 3       Barley and products          5142    Food  1000 tonnes     33.94
# 4        Maize and products          5521    Feed  1000 tonnes     33.94
#
#    longitude  ...   Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010  \
# 0      67.71  ...  3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0
# ...

# %%
wine_df = Raw_Master_df[Raw_Master_df["Item"].str.match("Wine")]
wine_df.fillna(0)
Clean_wine_df = wine_df.fillna(0)
Clean_wine_df.to_csv("Clean_wine_df.csv")

# %%
Alcoholic_Beverages_df = Raw_Master_df[Raw_Master_df["Item"].str.match("Alcoholic Beverages")]
Alcoholic_Beverages_df
Alcoholic_Beverages_df.fillna(0)
Clean_Alcoholic_Beverages_df = Alcoholic_Beverages_df.fillna(0)
Clean_Alcoholic_Beverages_df.to_csv("Clean_Alcoholic_Beverages_df.csv")

# %%
Alcoholic_Beverages_df.head()
# Out:
#     Area Abbreviation  Area Code                 Area  Item Code  \
# 74                AFG          2          Afghanistan       2924
# 195               ALB          3              Albania       2924
# 320               DZA          4              Algeria       2924
# 427               AGO          7               Angola       2924
# 545               ATG          8  Antigua and Barbuda       2924
#
#                     Item  Element Code Element         Unit  latitude  \
# 74   Alcoholic Beverages          5142    Food  1000 tonnes     33.94
# 195  Alcoholic Beverages          5142    Food  1000 tonnes     41.15
# 320  Alcoholic Beverages          5142    Food  1000 tonnes     28.03
# 427  Alcoholic Beverages          5142    Food  1000 tonnes    -11.20
# 545  Alcoholic Beverages          5142    Food  1000 tonnes     17.06
#
#      longitude  ...  Y2004  Y2005  Y2006  Y2007   Y2008   Y2009   Y2010  \
# 74       67.71  ...    5.0    3.0    4.0    3.0     3.0     3.0     3.0
# ...

# %%
Booze_df = pd.concat([Alcoholic_Beverages_df , wine_df], ignore_index = True)

# %%
Master_Booze_df = Booze_df.sort_values('Area')

# %%
Master_Booze_df
# Out:
#     Area Abbreviation  Area Code                                Area  \
# 0                 AFG          2                         Afghanistan
# 173               AFG          2                         Afghanistan
# 174               ALB          3                             Albania
# 1                 ALB          3                             Albania
# 2                 DZA          4                             Algeria
# 175               DZA          4                             Algeria
# 176               AGO          7                              Angola
# 3                 AGO          7                              Angola
# 177               ATG          8                 Antigua and Barbuda
# 4                 ATG          8                 Antigua and Barbuda
# 5                 ARG          9                           Argentina
# 178               ARG          9                           Argentina
# 179               ARM          1                             Armenia
# ...

# %%
Master_Booze_df.to_csv("Master_Booze_df.csv")

# %%
for col in Clean_Alcoholic_Beverages_df: 
    print(col)
# Out:
# Area Abbreviation
# Area Code
# Area
# Item Code
# Item
# Element Code
# Element
# Unit
# latitude
# longitude
# Y1961
# Y1962
# Y1963
# Y1964
# Y1965
# Y1966
# Y1967
# Y1968
# Y1969
# Y1970
# Y1971
# Y1972
# Y1973
# Y1974
# Y1975
# Y1976
# Y1977
# Y1978
# Y1979
# Y1980
# Y1981
# Y1982
# Y1983
# Y1984
# Y1985
# Y1986
# Y1987
# Y1988
# Y1989
# Y1990
# Y1991
# Y1992
# Y1993
# Y1994
# Y1995
# Y1996
# Y1997
# Y1998
# Y1999
# Y2000
# Y2001
# Y2002
# Y2003
# Y2004
# Y2005
# Y2006
# Y2007
# Y2008
# Y2009
# Y2010
# Y2011
# Y2012
# Y2013

# %%
rds_connection_string =rds_connection_string = "postgres:Estarrol88@localhost:5432/Worldproduction_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['Alcoholic_Beverages']

# %%
Clean_Alcoholic_Beverages_df.to_sql(name='Alcoholic_Beverages', con=engine, if_exists='append', index=False)
